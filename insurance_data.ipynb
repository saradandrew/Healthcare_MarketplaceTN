# %%
import csv
import json
import pandas as pd

# %%
df = pd.read_csv("Resources/TNHealthPlans.csv", index_col=0)

# %%
df
# Out:
#             Company Plan Category         Plan ID  Premium  \
# Plan Type
# EPO            BCBS        Bronze  14002TN0400239   304.61
# EPO            BCBS        Bronze  14002TN0400058   307.70
# EPO            BCBS        Bronze  14002TN0400089   313.08
# EPO            BCBS        Bronze  14002TN0400253   334.36
# EPO            BCBS        Bronze  14002TN0400066   336.85
# ...             ...           ...             ...      ...
# EPO        Ambetter          Gold  70111TN0110006   415.23
# EPO        Ambetter        Silver  70111TN0120004   416.80
# EPO        Ambetter          Gold  70111TN0120006   431.20
# EPO        Ambetter          Gold  70111TN0110031   457.06
# EPO        Ambetter          Gold  70111TN0120034   474.65
#
#            Individual Deductible Individual Deductible Type  \
# Plan Type
# EPO                         9100                   Combined
# EPO                         8700                   Combined
# ...

# %%
df.to_json("static/js/data.js", orient="records", lines=True)
